# %%
                                            # Machine Learning Project #
                                             “Household Price Analysis”     
                                                Dipesh Kumar Barai

# %%
# Importing the libraries
import numpy as np               # for the algebric calculation  
import matplotlib.pyplot as plt  # to plot the dataset
import pandas as pd              # data manipulation

# Importing the dataset
dataset = pd.read_csv('Household Price Analysis1.csv')

# %%
# To check the 1st five dataset.
dataset.head()
# Out:
#    ID  Local Price  Bathrooms Count  Area_Sqft  Living Space  Garrage Count  \
# 0   1       4.9176              1.0      3.472         0.998            1.0
# 1   2       5.0208              1.0      3.531         1.500            2.0
# 2   3       4.5429              1.0      2.275         1.175            1.0
# 3   4       4.5573              1.0      4.050         1.232            1.0
# 4   5       5.0597              1.0      4.455         1.121            1.0
#
#    Rooms Count  Bedrooms Count  Age        Material      Level  Selling Price
# 0            7               4   42  Alumunium/Wood  Two story           25.9
# 1            7               4   62           Brick  Two story           29.5
# 2            6               3   40      Brick/Wood  Two story           27.9
# 3            6               3   54            Wood  Two story           25.9
# 4            6               3   42  Alumunium/Wood  Two story           29.9

# %%
# Statistical analysis
dataset.describe()
# Out:
#               ID  Local Price  Bathrooms Count  Area_Sqft  Living Space  \
# count  57.000000    57.000000        57.000000  57.000000     57.000000
# mean   29.000000     7.355858         1.377193   6.417904      1.428242
# std    16.598193     3.002137         0.502500   2.418404      0.609202
# min     1.000000     2.851100         1.000000   1.147300      0.125500
# 25%    15.000000     5.276500         1.000000   4.996900      1.107400
# 50%    29.000000     6.258200         1.000000   6.123600      1.357100
# 75%    43.000000     9.038400         1.500000   7.800000      1.683100
# max    57.000000    16.420200         3.000000  12.800000      3.420000
#
#        Garrage Count  Rooms Count  Bedrooms Count        Age  Selling Price
# count      57.000000    57.000000       57.000000  57.000000      57.000000
# mean        1.280702     6.526316        3.245614  36.035088      34.270175
# std         0.619746     2.391243        1.313130  13.947561      12.821229
# min         0.000000     1.000000        0.000000   3.000000      13.200000
# 25%         1.000000     6.000000        3.000000  30.000000      25.900000
# 50%         1.000000     6.000000        3.000000  36.000000      31.500000
# 75%         2.000000     8.000000        4.000000  44.000000      39.600000
# max         2.000000    15.000000        7.000000  66.000000      84.900000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
dataset.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C43FFE788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C438106C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44A9C088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44AD5188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44B0C2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44B443C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44B7D448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44BB5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44BC1188>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44BF8348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44C5E8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C44C956C8>]],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dataset1,figsize = (9,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4AE50888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4867DBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C486AEE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C486E9688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4871F3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C48756148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C48785E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C487BBC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C487C3A88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C487FBA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4AF80FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4AFBD148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4AFF5248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B02B348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B065448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B09E588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B0DBE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B110788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B1498C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B181948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B1B9A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B1F2B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B22CC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B264D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B29DE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B2D5F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B315048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B34B188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B384288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B3BC348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B3E6088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B41F188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B458288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B4923C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B4CA4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B501588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B53B6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B5747C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B5AD8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B5E6A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B61EA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B657B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B68FC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B6C9DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4B700EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BBC8F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BC06108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BC40208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BC78308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BCB0448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BCEA548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BD225C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BD59708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BD94808>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BDCD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BE04A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BE3DAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BE77BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BEAFD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BEE8E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BF20F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BF59FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BF96148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4BFCF248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C008348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C040488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C077508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C0B0608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C0EB748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C124848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C15C948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C195A08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C1CDB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C206C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C23ED48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C278E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C2AFF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C2EE088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C326188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C35E288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000C4C3973C8>]],
#       dtype=object)

# %%
# Problem 1(a)
# Plotting the Area Selling Price and Local Price data
plt.style.use('seaborn-whitegrid')
plt.figure()
plt.subplot(2,2,1)
plt.scatter(dataset['Selling Price'], dataset['Local Price'], marker='o',s=10, color = 'r')
plt.xlabel('Selling Price')
plt.ylabel('area selling price')
plt.title('Final selling price vs Area selling price')
# Plotting the Area Selling Price and Area_Sqft
plt.subplot(2,2,2)
plt.scatter(dataset['Selling Price'], dataset['Area_Sqft'], marker='o',s =10, color = 'blue')
plt.xlabel('Selling Price')
plt.ylabel('Area-Sqft')
plt.title('Final selling price vs Area-Sqft')
plt.show()

# %%
# The correlation between local price and selling price is 0.79 (So, there is a positive correlation between two variables)
# The correlation between Area_Sqft and selling price is 0.51 (So, there is also a positive correlation between two variables)

# %%
#Import seaborn libraries
import seaborn as sns
from pylab import *

# %%
# Problem 1(b)
#Computing correlation Matrix
dataset1 = dataset[['Local Price','Bathrooms Count','Area_Sqft','Living Space','Garrage Count','Rooms Count','Bedrooms Count','Age','Selling Price']]
corrmat = dataset1.corr()
corrmat

# The correlation between local price and selling price is 0.79 (So, there is a positive correlation between two variables)
# The correlation between Area_Sqft and selling price is 0.51 (So, there is also a positive correlation between two variables)
# The feature 'Age' variable is negatively correlated with another variables.
# Out:
#                  Local Price  Bathrooms Count  Area_Sqft  Living Space  \
# Local Price         1.000000         0.442454   0.311146      0.439033
# Bathrooms Count     0.442454         1.000000   0.612422      0.537542
# Area_Sqft           0.311146         0.612422   1.000000      0.648941
# Living Space        0.439033         0.537542   0.648941      1.000000
# Garrage Count       0.280286         0.327696   0.424984      0.428934
# Rooms Count         0.236704         0.463433   0.555061      0.833522
# Bedrooms Count      0.281522         0.263029   0.476592      0.813547
# Age                -0.177871         0.015913  -0.222979     -0.182360
# Selling Price       0.790234         0.526322   0.513818      0.789685
#
#                  Garrage Count  Rooms Count  Bedrooms Count       Age  \
# Local Price           0.280286     0.236704        0.281522 -0.177871
# Bathrooms Count       0.327696     0.463433        0.263029  0.015913
# Area_Sqft             0.424984     0.555061        0.476592 -0.222979
# Living Space          0.428934     0.833522        0.813547 -0.182360
# Garrage Count         1.000000     0.404615        0.418451 -0.124078
# Rooms Count           0.404615     1.000000        0.788393 -0.223296
# Bedrooms Count        0.418451     0.788393        1.000000 -0.073604
# Age                  -0.124078    -0.223296       -0.073604  1.000000
# Selling Price         0.400312     0.549480        0.500542 -0.210545
#
#                  Selling Price
# Local Price           0.790234
# Bathrooms Count       0.526322
# Area_Sqft             0.513818
# Living Space          0.789685
# Garrage Count         0.400312
# Rooms Count           0.549480
# Bedrooms Count        0.500542
# Age                  -0.210545
# Selling Price         1.000000

# %%
# Problem 1(c(i))
#adding an extra column 'Average Room Size'
dataset['Average Room Size'] = dataset['Living Space'] / dataset['Bedrooms Count']

# %%
# Problem 1(c(ii))
#adding an extra column '% of Area under Living space'
dataset['% of Area under Living space'] = dataset['Living Space']*100 / dataset['Area_Sqft']

# %%
# To check the 1st five row and feature variables
dataset.head()
# Out:
#    ID  Local Price  Bathrooms Count  Area_Sqft  Living Space  Garrage Count  \
# 0   1       4.9176              1.0      3.472         0.998            1.0
# 1   2       5.0208              1.0      3.531         1.500            2.0
# 2   3       4.5429              1.0      2.275         1.175            1.0
# 3   4       4.5573              1.0      4.050         1.232            1.0
# 4   5       5.0597              1.0      4.455         1.121            1.0
#
#    Rooms Count  Bedrooms Count  Age        Material      Level  Selling Price  \
# 0            7               4   42  Alumunium/Wood  Two story           25.9
# 1            7               4   62           Brick  Two story           29.5
# 2            6               3   40      Brick/Wood  Two story           27.9
# 3            6               3   54            Wood  Two story           25.9
# 4            6               3   42  Alumunium/Wood  Two story           29.9
#
#    % of Area under Living space  Average Room Size
# 0                     28.744240           0.249500
# 1                     42.480884           0.375000
# 2                     51.648352           0.391667
# 3                     30.419753           0.410667
# 4                     25.162738           0.373667

# %%
# Problem 1(d)
# for building a multiple regression model we should have to select the independent and dependent variables
X = dataset.iloc[:, [1,2,3,4,5,6,7,8]].values   # independent variables
y = dataset.iloc[:, 11].values                  # dependent variables

# %%
# Build a Machine Learning Modelto predict “Selling Price” through other variables
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state = 0) # we take 80% tranning set and 20% test dataset

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
# Import the sklearn libraries
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)    # Coefficient of determination
# Out:
# 0.8550047322613521

# %%
# The coefficient of determination is 0.8550047322613521 means that 85 percent of the variance in Y is predictable from X.

# %%
# Building a model (Backword Elimination)
# Using Backword Elimination we will select the actual independent variable to make the model accurate.
# By observing p-value(0.05) we will decide whitch wanna keep (independent variable) and whitch wanna through out.

# %%
# Backword Elemination step by step
#step-1 select a significance level to stay in the model (e.g Sl=0.05)
#step-2 Fill the full model with all possible predictor
#step-3 Consider the predictor with the hightest p-value, if P > Sl=0.05, go to next step otherwise finish
#step-4 Remove the predictor
#step-5 Fit the model without this variable

# %%
# Building a optimal model (For the multiple linear regression model we will add an extra column for the the constant value(b0) whitch is 57*1 vector)
import statsmodels.api as sm
X = np.append(arr = np.ones((57, 1)).astype(int), values = X, axis = 1)

# %%
# Using Ordinary Least Square Method we will calculate p-value for all independent variables
X_opt = X[:, [0, 1, 2, 3, 4, 5,6,7,8]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit() # X_opt is the independent variable and y is the dependet variable.
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     58.80
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           3.49e-22
# Time:                        10:11:10   Log-Likelihood:                -157.97
# No. Observations:                  57   AIC:                             333.9
# Df Residuals:                      48   BIC:                             352.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.5453      3.053      1.161      0.251      -2.592       9.683
# x1             2.3221      0.236      9.824      0.000       1.847       2.797
# x2            -3.0511      1.778     -1.716      0.093      -6.627       0.525
# x3            -0.0695      0.354     -0.196      0.845      -0.781       0.642
# x4            18.9933      2.295      8.274      0.000      14.378      23.609
# x5             1.3375      1.058      1.264      0.212      -0.790       3.465
# x6             0.1005      0.504      0.199      0.843      -0.913       1.114
# x7            -3.7924      0.910     -4.166      0.000      -5.623      -1.962
# x8             0.0306      0.046      0.663      0.511      -0.062       0.124
# ==============================================================================
# Omnibus:                       12.160   Durbin-Watson:                   1.165
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.468
# Skew:                           1.063   Prob(JB):                      0.00196
# Kurtosis:                       3.853   Cond. No.                         230.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# From this result x3 = Area_Sqft has a hight p-value(0.845), Using backword elemination we will delect the following ind variable
X_opt = X[:, [0, 1, 2, 4, 5, 6, 7, 8]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     68.54
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           4.11e-23
# Time:                        10:11:11   Log-Likelihood:                -157.99
# No. Observations:                  57   AIC:                             332.0
# Df Residuals:                      49   BIC:                             348.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3568      2.869      1.170      0.248      -2.409       9.123
# x1             2.3295      0.231     10.081      0.000       1.865       2.794
# x2            -3.2021      1.588     -2.017      0.049      -6.393      -0.011
# x3            18.8835      2.204      8.566      0.000      14.454      23.313
# x4             1.3026      1.033      1.261      0.213      -0.773       3.378
# x5             0.1101      0.497      0.221      0.826      -0.889       1.109
# x6            -3.8065      0.899     -4.236      0.000      -5.612      -2.001
# x7             0.0329      0.044      0.742      0.462      -0.056       0.122
# ==============================================================================
# Omnibus:                       11.921   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.145
# Skew:                           1.053   Prob(JB):                      0.00231
# Kurtosis:                       3.826   Cond. No.                         214.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again From the previous result x5 = Rooms Count has a hight p-value(0.826), Using backword elemination we will delect the following ind variable
X_opt = X[:, [0, 1,2, 4, 5,7,8]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     81.51
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           4.44e-24
# Time:                        10:11:12   Log-Likelihood:                -158.02
# No. Observations:                  57   AIC:                             330.0
# Df Residuals:                      50   BIC:                             344.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6065      2.613      1.380      0.174      -1.642       8.855
# x1             2.3126      0.216     10.700      0.000       1.878       2.747
# x2            -3.0962      1.500     -2.065      0.044      -6.108      -0.084
# x3            19.0724      2.013      9.473      0.000      15.029      23.116
# x4             1.3074      1.023      1.278      0.207      -0.747       3.362
# x5            -3.7228      0.807     -4.611      0.000      -5.344      -2.101
# x6             0.0301      0.042      0.715      0.478      -0.054       0.115
# ==============================================================================
# Omnibus:                       11.281   Durbin-Watson:                   1.155
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.332
# Skew:                           1.031   Prob(JB):                      0.00346
# Kurtosis:                       3.718   Cond. No.                         194.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again From this result x6 = Age has a hight p-value(0.478), Using backword elemination we will delect the following ind variable
X_opt = X[:, [0, 1,2, 4, 5,7]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     98.65
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           5.44e-25
# Time:                        10:11:12   Log-Likelihood:                -158.31
# No. Observations:                  57   AIC:                             328.6
# Df Residuals:                      51   BIC:                             340.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7301      2.077      2.277      0.027       0.560       8.900
# x1             2.2911      0.213     10.756      0.000       1.864       2.719
# x2            -2.8374      1.448     -1.959      0.056      -5.745       0.070
# x3            18.7036      1.937      9.658      0.000      14.816      22.592
# x4             1.2349      1.013      1.219      0.228      -0.799       3.268
# x5            -3.6050      0.787     -4.584      0.000      -5.184      -2.026
# ==============================================================================
# Omnibus:                        9.732   Durbin-Watson:                   1.105
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.420
# Skew:                           0.956   Prob(JB):                      0.00901
# Kurtosis:                       3.559   Cond. No.                         41.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again From this result x4 = Garrage Count has a hight p-value(0.228), Using backword elemination we will delect the following ind variable
X_opt = X[:, [0, 1,2, 4, 7]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     121.8
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           9.53e-26
# Time:                        10:11:12   Log-Likelihood:                -159.13
# No. Observations:                  57   AIC:                             328.3
# Df Residuals:                      52   BIC:                             338.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.0844      2.066      2.461      0.017       0.938       9.231
# x1             2.3157      0.213     10.869      0.000       1.888       2.743
# x2            -2.5510      1.436     -1.777      0.081      -5.432       0.330
# x3            18.7313      1.946      9.628      0.000      14.827      22.635
# x4            -3.4162      0.775     -4.410      0.000      -4.971      -1.862
# ==============================================================================
# Omnibus:                        9.953   Durbin-Watson:                   1.086
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.751
# Skew:                           0.979   Prob(JB):                      0.00763
# Kurtosis:                       3.525   Cond. No.                         41.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Again From this result x2 = Bathrooms Count has a hight p-value(0.081), Using backword elemination we will delect the following ind variable
X_opt = X[:, [0, 1, 4, 7]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     155.0
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           3.22e-26
# Time:                        10:11:12   Log-Likelihood:                -160.81
# No. Observations:                  57   AIC:                             329.6
# Df Residuals:                      53   BIC:                             337.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2341      1.821      1.776      0.081      -0.418       6.886
# x1             2.2252      0.211     10.544      0.000       1.802       2.648
# x2            16.9948      1.716      9.903      0.000      13.553      20.437
# x3            -2.9593      0.746     -3.970      0.000      -4.455      -1.464
# ==============================================================================
# Omnibus:                        8.447   Durbin-Watson:                   0.924
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                8.447
# Skew:                           0.941   Prob(JB):                       0.0146
# Kurtosis:                       3.135   Cond. No.                         29.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again From the previous result Constant Value has a hight p-value(0.081), Using backword elemination we will delect the following ind variable
X_opt = X[:, [1, 4, 7]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              1356.
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):                    8.69e-51
# Time:                        10:11:13   Log-Likelihood:                         -162.46
# No. Observations:                  57   AIC:                                      330.9
# Df Residuals:                      54   BIC:                                      337.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             2.4270      0.181     13.382      0.000       2.063       2.791
# x2            16.8784      1.749      9.651      0.000      13.372      20.385
# x3            -2.4627      0.705     -3.494      0.001      -3.876      -1.050
# ==============================================================================
# Omnibus:                        6.114   Durbin-Watson:                   1.007
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                6.103
# Skew:                           0.796   Prob(JB):                       0.0473
# Kurtosis:                       2.816   Cond. No.                         28.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Now our model is ready for the prediction

# %%
# Problem 1(e)
# Conclusion
# Now all the p-values are less than 0.05.
# By using the Backword Elemination method Local Price, Living Space and Bedrooms Count are the accurate independent variable for predicting the selling price.

# %%
                                                   # Thank You #
